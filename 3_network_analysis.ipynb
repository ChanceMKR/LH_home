# %%
import pandas as pd

# %%
jinju = pd.read_csv('./data/jinju.csv', index_col=0)
print(jinju.shape)
jinju.head(2)
# Out:
# (13207, 10)
#    도로조건  계약면적(㎡)  건축년도  year  month  전세전환가격  coivd  price_per_m2  전월세구분_월세  \
# 0    25     12.0  2016  2019      2    8435      0    702.916667      True
# 1     8     12.0  2016  2019      1    4500      0    375.000000     False
#
#    전월세구분_전세
# 0     False
# 1      True
