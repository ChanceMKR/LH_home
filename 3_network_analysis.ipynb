# %%
import pandas as pd

# %%
jinju = pd.read_csv('./data/jinju.csv', index_col=0)
print(jinju.shape)
jinju.head(2)
# Out:
# (13207, 20)
#             시군구    번지  도로조건  계약면적(㎡)    계약년월  계약일  보증금(만원)  월세(만원)  건축년도  \
# 0  경상남도 진주시 가좌동  1***    25     12.0  201902   16      200      35  2016
# 1  경상남도 진주시 가좌동  1***     8     12.0  201901    5     4500       0  2016
#
#        도로명          경도         위도  year  month              location  전월세전환율  \
# 0  가좌길74번길  128.105889  35.157466  2019      2  경상남도 진주시 가좌동 가좌길74번길     5.1
# 1  가좌길78번길  128.105889  35.157466  2019      1  경상남도 진주시 가좌동 가좌길78번길     5.3
#
#    전세전환가격  coivd  price_per_m2  전월세구분_월세
# 0    8435      0    702.916667      True
# 1    4500      0    375.000000     False

# %%
jinju.drop('전월세구분_월세')
